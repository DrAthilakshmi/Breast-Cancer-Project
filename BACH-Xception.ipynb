# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, MaxPooling2D, Dropout, Flatten, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD , Adam
from tensorflow.keras.callbacks import CSVLogger
import pandas as pd
from sklearn.metrics import classification_report
import os
import warnings
warnings.filterwarnings( 'ignore' )

# %%
train_dir = '/content/drive/MyDrive/BACHAugment'
test_dir = '/content/drive/MyDrive/BACHtest'

# Define the image size and batch size
image_size = (224, 224)
batch_size = 32

random_seed = np.random.seed(1142)
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    featurewise_center=True,
    featurewise_std_normalization=True,
    validation_split= 0.2)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size= image_size,
    batch_size=batch_size,
    seed = random_seed,
    shuffle=False,
    subset = 'training',
    class_mode='categorical')

val_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size= image_size,
    batch_size=batch_size,
    seed = random_seed,
    shuffle=False,
    subset = 'validation',
    class_mode='categorical')

test_datagen=ImageDataGenerator(rescale=1./255)
test_generator =test_datagen.flow_from_directory(test_dir,
                                                  target_size=image_size,
                                                  batch_size=batch_size,
                                                  seed=random_seed,
                                                  shuffle=False,
                                                  class_mode='categorical') # set as training data
# Out:
# Found 3368 images belonging to 4 classes.
# Found 840 images belonging to 4 classes.
# Found 103 images belonging to 4 classes.

# %%
# base_model = Xception(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# x = base_model.output
# x = GlobalAveragePooling2D()(x)
# x = Dense(512, activation='relu')(x)
# x = Dropout(0.2)(x)
# output = Dense(4, activation='softmax')(x)

# model = Model(inputs=base_model.input, outputs=output)


# optimizer = Adam(learning_rate=1e-2)
# # Compile the model
# model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# model.summary()

def create_model():

    METRICS = [
    'accuracy',
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall'),
    tf.keras.metrics.AUC(name='AUC'),
    ]

    model = Sequential([Xception(input_shape=(image_size[0], image_size[1], 3),
                                                              include_top=False),
                               Conv2D(32, (3,3),activation="relu"),
                               BatchNormalization(),
                               MaxPooling2D(2,2),
                               Dropout(0.3),

                               Flatten(),
                               Dense(64, activation="relu"),
                               Dense(4, activation="softmax"),
                               ])
    model.compile(optimizer=SGD(learning_rate = 0.001), loss="categorical_crossentropy", metrics=METRICS)

    return model

model = create_model()
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 7, 7, 2048)        20861480
#
#  conv2d_14 (Conv2D)          (None, 5, 5, 32)          589856
#
#  batch_normalization_14 (Bat  (None, 5, 5, 32)         128
#  chNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 32)          0
#
#  flatten_2 (Flatten)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 21,459,980
# Trainable params: 21,405,388
# Non-trainable params: 54,592
# _________________________________________________________________

# %%
csv_logger = CSVLogger('/content/drive/MyDrive/BACH-Results/XceptionNet/training_results.csv')

# Train the model
history = model.fit(train_generator, epochs=100, validation_data=val_generator, callbacks=[csv_logger])
# Out:
# Epoch 1/100
# 106/106 [==============================] - 99s 804ms/step - loss: 1.8061 - accuracy: 0.2782 - precision: 0.2858 - recall: 0.1559 - AUC: 0.5283 - val_loss: 1.5187 - val_accuracy: 0.3048 - val_precision: 0.2912 - val_recall: 0.0988 - val_AUC: 0.5617
# Epoch 2/100
# 106/106 [==============================] - 77s 725ms/step - loss: 1.3741 - accuracy: 0.3887 - precision: 0.4587 - recall: 0.1862 - AUC: 0.6443 - val_loss: 1.3672 - val_accuracy: 0.3583 - val_precision: 0.4078 - val_recall: 0.0869 - val_AUC: 0.6171
# Epoch 3/100
# 106/106 [==============================] - 85s 801ms/step - loss: 1.1553 - accuracy: 0.4979 - precision: 0.6297 - recall: 0.2883 - AUC: 0.7553 - val_loss: 1.3359 - val_accuracy: 0.3845 - val_precision: 0.4419 - val_recall: 0.1131 - val_AUC: 0.6413
# Epoch 4/100
# 106/106 [==============================] - 77s 728ms/step - loss: 0.9461 - accuracy: 0.6161 - precision: 0.7485 - recall: 0.4118 - AUC: 0.8487 - val_loss: 1.3098 - val_accuracy: 0.4048 - val_precision: 0.4886 - val_recall: 0.1274 - val_AUC: 0.6614
# Epoch 5/100
# 106/106 [==============================] - 77s 723ms/step - loss: 0.8018 - accuracy: 0.6912 - precision: 0.8003 - recall: 0.5068 - AUC: 0.8989 - val_loss: 1.2920 - val_accuracy: 0.4012 - val_precision: 0.5216 - val_recall: 0.1869 - val_AUC: 0.6765
# Epoch 6/100
# 106/106 [==============================] - 78s 731ms/step - loss: 0.6550 - accuracy: 0.7755 - precision: 0.8674 - recall: 0.6256 - AUC: 0.9397 - val_loss: 1.2869 - val_accuracy: 0.4226 - val_precision: 0.5335 - val_recall: 0.2274 - val_AUC: 0.6909
# Epoch 7/100
# 106/106 [==============================] - 77s 728ms/step - loss: 0.5265 - accuracy: 0.8412 - precision: 0.9165 - recall: 0.7239 - AUC: 0.9680 - val_loss: 1.2584 - val_accuracy: 0.4512 - val_precision: 0.5281 - val_recall: 0.2464 - val_AUC: 0.7080
# Epoch 8/100
# 106/106 [==============================] - 77s 723ms/step - loss: 0.4223 - accuracy: 0.8916 - precision: 0.9425 - recall: 0.8026 - AUC: 0.9828 - val_loss: 1.2615 - val_accuracy: 0.4464 - val_precision: 0.5511 - val_recall: 0.2631 - val_AUC: 0.7120
# Epoch 9/100
# 106/106 [==============================] - 78s 735ms/step - loss: 0.3438 - accuracy: 0.9264 - precision: 0.9583 - recall: 0.8667 - AUC: 0.9900 - val_loss: 1.2553 - val_accuracy: 0.4488 - val_precision: 0.5364 - val_recall: 0.2631 - val_AUC: 0.7181
# Epoch 10/100
# 106/106 [==============================] - 86s 807ms/step - loss: 0.2868 - accuracy: 0.9451 - precision: 0.9675 - recall: 0.9011 - AUC: 0.9942 - val_loss: 1.2519 - val_accuracy: 0.4619 - val_precision: 0.5536 - val_recall: 0.3012 - val_AUC: 0.7273
# Epoch 11/100
# 106/106 [==============================] - 75s 707ms/step - loss: 0.2480 - accuracy: 0.9486 - precision: 0.9661 - recall: 0.9130 - AUC: 0.9961 - val_loss: 1.2761 - val_accuracy: 0.4512 - val_precision: 0.5348 - val_recall: 0.3202 - val_AUC: 0.7245
# Epoch 12/100
# 106/106 [==============================] - 76s 711ms/step - loss: 0.2133 - accuracy: 0.9641 - precision: 0.9788 - recall: 0.9326 - AUC: 0.9970 - val_loss: 1.2638 - val_accuracy: 0.4524 - val_precision: 0.5281 - val_recall: 0.3024 - val_AUC: 0.7262
# Epoch 13/100
# 106/106 [==============================] - 78s 730ms/step - loss: 0.1771 - accuracy: 0.9745 - precision: 0.9850 - recall: 0.9531 - AUC: 0.9985 - val_loss: 1.2817 - val_accuracy: 0.4583 - val_precision: 0.5305 - val_recall: 0.3214 - val_AUC: 0.7269
# Epoch 14/100
# 106/106 [==============================] - 76s 717ms/step - loss: 0.1546 - accuracy: 0.9789 - precision: 0.9860 - recall: 0.9626 - AUC: 0.9992 - val_loss: 1.2645 - val_accuracy: 0.4690 - val_precision: 0.5456 - val_recall: 0.3345 - val_AUC: 0.7346
# Epoch 15/100
# 106/106 [==============================] - 78s 730ms/step - loss: 0.1287 - accuracy: 0.9828 - precision: 0.9895 - recall: 0.9751 - AUC: 0.9995 - val_loss: 1.2932 - val_accuracy: 0.4833 - val_precision: 0.5490 - val_recall: 0.3536 - val_AUC: 0.7314
# Epoch 16/100
# 106/106 [==============================] - 77s 721ms/step - loss: 0.1122 - accuracy: 0.9875 - precision: 0.9925 - recall: 0.9789 - AUC: 0.9994 - val_loss: 1.2716 - val_accuracy: 0.4798 - val_precision: 0.5486 - val_recall: 0.3560 - val_AUC: 0.7393
# Epoch 17/100
# 106/106 [==============================] - 78s 735ms/step - loss: 0.0995 - accuracy: 0.9890 - precision: 0.9928 - recall: 0.9804 - AUC: 0.9997 - val_loss: 1.2738 - val_accuracy: 0.4869 - val_precision: 0.5420 - val_recall: 0.3607 - val_AUC: 0.7429
# Epoch 18/100
# 106/106 [==============================] - 77s 726ms/step - loss: 0.0970 - accuracy: 0.9878 - precision: 0.9922 - recall: 0.9837 - AUC: 0.9997 - val_loss: 1.2672 - val_accuracy: 0.4881 - val_precision: 0.5530 - val_recall: 0.3726 - val_AUC: 0.7448
# Epoch 19/100
# 106/106 [==============================] - 78s 732ms/step - loss: 0.0852 - accuracy: 0.9893 - precision: 0.9946 - recall: 0.9855 - AUC: 0.9998 - val_loss: 1.2799 - val_accuracy: 0.4905 - val_precision: 0.5467 - val_recall: 0.3762 - val_AUC: 0.7455
# Epoch 20/100
# 106/106 [==============================] - 77s 726ms/step - loss: 0.0750 - accuracy: 0.9920 - precision: 0.9955 - recall: 0.9884 - AUC: 0.9999 - val_loss: 1.2840 - val_accuracy: 0.4917 - val_precision: 0.5444 - val_recall: 0.3798 - val_AUC: 0.7451
# Epoch 21/100
# 106/106 [==============================] - 78s 738ms/step - loss: 0.0719 - accuracy: 0.9947 - precision: 0.9961 - recall: 0.9920 - AUC: 0.9999 - val_loss: 1.2642 - val_accuracy: 0.4952 - val_precision: 0.5563 - val_recall: 0.3940 - val_AUC: 0.7539
# Epoch 22/100
# 106/106 [==============================] - 76s 719ms/step - loss: 0.0683 - accuracy: 0.9923 - precision: 0.9949 - recall: 0.9881 - AUC: 0.9999 - val_loss: 1.2780 - val_accuracy: 0.4857 - val_precision: 0.5458 - val_recall: 0.3762 - val_AUC: 0.7488
# Epoch 23/100
# 106/106 [==============================] - 77s 720ms/step - loss: 0.0614 - accuracy: 0.9932 - precision: 0.9964 - recall: 0.9905 - AUC: 0.9999 - val_loss: 1.2760 - val_accuracy: 0.4964 - val_precision: 0.5411 - val_recall: 0.3917 - val_AUC: 0.7538
# Epoch 24/100
# 106/106 [==============================] - 78s 736ms/step - loss: 0.0580 - accuracy: 0.9941 - precision: 0.9973 - recall: 0.9920 - AUC: 0.9999 - val_loss: 1.2805 - val_accuracy: 0.4964 - val_precision: 0.5414 - val_recall: 0.3893 - val_AUC: 0.7490
# Epoch 25/100
# 106/106 [==============================] - 77s 722ms/step - loss: 0.0536 - accuracy: 0.9958 - precision: 0.9967 - recall: 0.9944 - AUC: 0.9999 - val_loss: 1.2915 - val_accuracy: 0.4929 - val_precision: 0.5607 - val_recall: 0.4012 - val_AUC: 0.7493
# Epoch 26/100
# 106/106 [==============================] - 78s 734ms/step - loss: 0.0477 - accuracy: 0.9973 - precision: 0.9976 - recall: 0.9952 - AUC: 1.0000 - val_loss: 1.2776 - val_accuracy: 0.5095 - val_precision: 0.5563 - val_recall: 0.4060 - val_AUC: 0.7562
# Epoch 27/100
# 106/106 [==============================] - 77s 724ms/step - loss: 0.0459 - accuracy: 0.9976 - precision: 0.9985 - recall: 0.9952 - AUC: 1.0000 - val_loss: 1.2806 - val_accuracy: 0.5036 - val_precision: 0.5523 - val_recall: 0.4024 - val_AUC: 0.7545
# Epoch 28/100
# 106/106 [==============================] - 79s 740ms/step - loss: 0.0406 - accuracy: 0.9982 - precision: 0.9982 - recall: 0.9970 - AUC: 1.0000 - val_loss: 1.2792 - val_accuracy: 0.5048 - val_precision: 0.5507 - val_recall: 0.4012 - val_AUC: 0.7546
# Epoch 29/100
#  68/106 [==================>...........] - ETA: 23s - loss: 0.0438 - accuracy: 0.9963 - precision: 0.9981 - recall: 0.9940 - AUC: 1.0000

# %%
from sklearn.metrics import confusion_matrix

# Assuming you have a trained model called 'model' and a test generator called 'test_generator'
# Generate predictions for the test data
predictions = model.predict(test_generator)

# Convert predictions into labels (assuming one-hot encoding)
predicted_labels = np.argmax(predictions, axis=1)

# Get the true labels from the test generator
true_labels = test_generator.classes

# Get the class labels from the test generator
class_labels = list(test_generator.class_indices.keys())

# Create the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = np.arange(len(class_labels))
plt.xticks(tick_marks, class_labels, rotation=45)
plt.yticks(tick_marks, class_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Add text annotations in each cell
thresh = cm.max() / 2.0
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, format(cm[i, j], 'd'),
                 ha="center", va="center",
                 color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.show()
